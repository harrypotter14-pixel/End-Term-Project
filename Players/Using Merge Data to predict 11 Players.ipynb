# %%
#the merged data with Player Strike Rate
import pandas as pd 


MD= pd.read_csv("MergeFinal_1.csv")
MD
# Out:
#              Team1      Team2   Toss_winner Toss_decision  Player_of_match  \
# 0        Australia   Pakistan     Australia           bat          MS Wade
# 1        Australia   Pakistan     Australia           bat  Mohammad Hafeez
# 2        Australia   Pakistan     Australia         field        SPD Smith
# 3        Australia   Pakistan     Australia           bat        DA Warner
# 4        Australia   Pakistan     Australia           bat        DA Warner
# ...            ...        ...           ...           ...              ...
# 1898  South Africa  Australia     Australia           bat        KJ Abbott
# 1899  South Africa  Australia  South Africa           bat        DA Warner
# 1900  South Africa  Sri Lanka  South Africa         field      Imran Tahir
# 1901  South Africa  Sri Lanka     Sri Lanka         field     F du Plessis
# 1902  South Africa  Sri Lanka  South Africa         field      D Pretorius
#
# ...

# %%
#MD.to_csv('merge.csv')

# %%
#info about the null values in the dataset
MD.info()
values_missing =MD.isnull().sum()
values_missing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1903 entries, 0 to 1902
# Columns: 162 entries, Team1 to Player22_StrikeRate
# dtypes: float64(22), int64(113), object(27)
# memory usage: 2.4+ MB
# Team1                    0
# Team2                    0
# Toss_winner              0
# Toss_decision            0
# Player_of_match          0
#                       ...
# Player18_StrikeRate     75
# Player19_StrikeRate     83
# Player20_StrikeRate     96
# Player21_StrikeRate    106
# Player22_StrikeRate    121
# Length: 162, dtype: int64

# %%
#the two variable that we need to predict the players
Players_1 = MD[['Players_1','Player1_StrikeRate']]
cols = ['Player1_StrikeRate','Players_1']
SR= Players_1[cols]
SR.head()
# Out:
#    Player1_StrikeRate   Players_1
# 0              158.33     G Malla
# 1              101.61    C Carter
# 2              306.90  KJ Coetzer
# 3              224.39  KJ Coetzer
# 4               60.00     PJ Moor

# %%
#applying Random Forest Classifier
x = MD[["Player1_StrikeRate"]]
y= MD[["Players_1"]]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
#implement random forest Classifier algorithm with no. of estimators means
#number of trees you want to build before taking the maximum voting or averages of predictions. 
rf = RandomForestClassifier(1)

rf.fit(x_train, y_train.values.ravel())
print("Accuracy score (validation): {0:.3f}".format(rf.score(x_test, y_test)))
result= rf.predict(x_test)
result
# Out:
# Accuracy score (validation): 0.013
# array(['Ayesha Zafar', 'CH Gayle', 'AM Rahane', 'CH Gayle', 'SW Bates',
#        'DM Gondaria', 'KL Rahul', 'DC Stovell', 'Imran Nazir',
#        'RG Mukasa', 'MDKJ Perera', 'DG Brownlie', 'V Kohli', 'L Vincent',
#        'Javed Omar', 'ER Dwivedi', 'Tamim Iqbal', 'MJ Guptill',
#        'Ayasha Rahman', 'BB McCullum', 'JEC Franklin', 'SR Watson',
#        'RJ Nicol', 'AN Petersen', 'BJ Haddin', 'Rajin Saleh',
#        'DPMD Jayawardene', 'JM How', 'Mohammad Shahzad', 'AJ Strauss',
#        'AM Rahane', 'AM Rahane', 'BRM Taylor', 'ER Dwivedi',
#        'Tamim Iqbal', 'WU Tharanga', 'Tamim Iqbal', 'RV Uthappa',
#        'HM Amla', 'RV Uthappa', 'BB McCullum', 'MH Cross', 'KJ Coetzer',
#        'Noor Ali Zadran', 'Tamim Iqbal', 'DA Warner', 'AN Petersen',
#        'DA Warner', 'AC Gilchrist', 'Tamim Iqbal', 'SJ Myburgh',
#        'BB McCullum', 'AJ Strauss', 'ST Jayasuriya', 'AM Rahane',
# ...

# %%
Player1=[
    'EC Joyce', 'Tamim Iqbal', 'J Dunn', 'JJ Roy', 'MH Cross',
       'L Vincent', 'DM de Silva', 'GC Smith', 'V Sehwag', 'GC Smith',
       'AJ Strauss', 'Tamim Iqbal', 'L Vincent', 'MDKJ Perera',
       'G Gambhir', 'WU Tharanga', 'Q de Kock', 'MN van Wyk',
       'Usman Ghani', 'JJ Roy', 'Tamim Iqbal', 'HH Gibbs', 'TMK Mawoyo',
       'Tamim Iqbal', 'HM Amla', 'WTS Porterfield', 'Kamran Akmal',
       'WU Tharanga', 'RS Bopara', 'LMP Simmons', 'LMP Simmons',
       'AJ Strauss', 'Q de Kock', 'RJ Nicol', 'AC Jayangani', 'L Vincent',
       'Tamim Iqbal', 'T Duffin', 'Tamim Iqbal', 'JJ Roy',
       'MD Gunathilaka', 'NE Bolton', 'NC Dodd', 'AN Cook', 'HM Amla',
       'Q de Kock', 'GC Smith', 'LMP Simmons', 'SA Fritz', 'L Vincent',
       'Salman Butt', 'Jitin Singh', 'L Lee', 'LMP Simmons',
       'Tamim Iqbal', 'WU Tharanga', 'ML Hayden', 'Tamim Iqbal',
       'MM Lanning', 'Tamim Iqbal', 'Kycia A Knight', 'Q de Kock',
       'RJ Nicol', 'Tamim Iqbal', 'Tamim Iqbal', 'AC Gilchrist',
       'SA Fritz', 'Q de Kock', 'Azhar Ali', 'L Lee', 'HK Matthews',
       'A Balbirnie', 'AA Mulla', 'CM Edwards', 'CH Gayle', 'AN Cook',
       'SE Marsh', 'SA Fritz', 'MDKJ Perera', 'L Vincent', 'HM Amla',
       'CR Suryawanshi', 'S Sohal', 'Kamran Akmal', 'Tamim Iqbal',
       'DS Smith', 'H Patel', 'F Baleri', 'AC Jayangani', 'Nasir Jamshed',
       'Tamim Iqbal', 'SR Watson', 'PRCS Kumarihami', 'SR Watson',
       'MS Wade', 'AC Jayangani', 'Sulaimon Runsewe', 'S Sohal',
       'RG Sharma', 'AC Gilchrist', 'Tamim Iqbal', 'LMP Simmons',
       'Tamim Iqbal', 'CH Gayle', 'GC Smith', 'Q de Kock', 'SW Bates',
       'AN Cook', 'JJ Roy', 'CH Gayle', 'KD Karthik', 'G Gambhir',
       'Mohammad Hafeez', 'Rohan Mustafa', 'DM de Silva', 'ML Hayden',
       'E Lewis', 'WTS Porterfield', 'EC Joyce', 'KL Rahul', 'PS Airee',
       'Tamim Iqbal', 'AJ Finch', 'Tamim Iqbal', 'MJ Guptill',
       'H Masakadza', 'LMP Simmons', 'RS Bopara', 'MJ Guptill',
       'V Sehwag', 'WU Tharanga', 'LMP Simmons', 'V Kohli',
       'Noor Ali Zadran', 'Javed Omar', 'Tamim Iqbal', 'AN Cook',
       'CM Edwards', 'V Sehwag', 'LA Pomersbach', 'AC Jayangani',
       'Azhar Ali', 'V Sibanda', 'WU Tharanga', 'FDM Karunaratne',
       'Tamim Iqbal', 'HM Amla', 'Tamim Iqbal', 'MJ Guptill', 'AM Rahane',
       'CH Gayle', 'Q de Kock', 'IR Bell', 'IR Bell', 'BB Chari',
       'Tamim Iqbal', 'IR Bell', 'Kamran Akmal', 'Tamim Iqbal',
       'Kamran Akmal', 'HM Amla', 'V Sehwag', 'WU Tharanga', 'RG Sharma',
       'Tamim Iqbal', 'SJ Baard', 'SE Marsh', 'Tamim Iqbal',
       'Tamim Iqbal', 'WTS Porterfield', 'MJ Guptill', 'V Sehwag',
       'LMP Simmons', 'ST Jayasuriya', 'Tamim Iqbal', 'Sagar Pun',
       'CH Gayle', 'Tamim Iqbal', 'L Vincent', 'AM Rahane', 'MDKJ Perera',
       'Kycia A Knight', 'Tamim Iqbal', 'J Chinunga', 'AC Gilchrist',
       'WW Hinds', 'L Lee', 'AN Cook', 'V Sehwag', 'DP Hyatt', 'AJ Finch',
       'L Vincent', 'Tamim Iqbal', 'HM Amla', 'V Kohli', 'TM Dilshan',
       'Salman Butt', 'HM Amla', 'SA Fritz', 'RJ Nicol', 'V Kohli',
       'SR Watson', 'AC Jayangani', 'LA Pomersbach', 'Hazratullah',
       'CH Gayle', 'MJ Guptill', 'WU Tharanga', 'V Sehwag', 'AJ Finch',
       'TM Dilshan', 'Anamul Haque', 'WU Tharanga', 'BB Chari', 'HM Amla',
       'Tamim Iqbal', 'RG Sharma', 'BJ Haddin', 'HH Gibbs', 'G Gambhir',
       'Mohammad Shahzad', 'Tamim Iqbal', 'MDKJ Perera', 'Azhar Ali',
       'V Sibanda', 'MN van Wyk', 'SR Watson', 'GWHM Perera',
       'Tamim Iqbal', 'AN Cook', 'SR Watson', 'AJ Strauss', 'CH Gayle',
       'JD Ryder', 'Imrul Kayes', 'DA Warner', 'DPMD Jayawardene',
       'HM Amla', 'Rajin Saleh', 'KJ Coetzer', 'Tamim Iqbal',
       'WU Tharanga', 'MJ Guptill', 'AC Gilchrist', 'AC Jayangani',
       'GC Smith', 'CH Gayle', 'Tamim Iqbal', 'Ahmed Shehzad',
       'Tamim Iqbal', 'HM Amla', 'R Dravid', 'AC Gilchrist',
       'DM Richards', 'LMP Simmons', 'SA Yadav', 'MS Harris', 'DF Watts',
       'Sagar Pun', 'Azhar Ali', 'Tamim Iqbal', 'MDKJ Perera',
       'MJ Paterlini', 'LA Pomersbach', 'SC Ganguly', 'L Vincent',
       'B Masaba', 'S Dhawan', 'TM Dilshan', 'LMP Simmons', 'JJ Roy',
       'JJ Roy', 'J Charles', 'Tamim Iqbal', 'SR Watson', 'SC Ganguly',
       'Tamim Iqbal', 'H Masakadza', 'GC Smith', 'S Sohal', 'TM Dilshan',
       'WU Tharanga', 'WTS Porterfield', 'CR Suryawanshi', 'WU Tharanga',
       'A Bonora', 'AN Cook', 'KJ Coetzer', 'CH Gayle', 'L Lee',
       'WU Tharanga', 'F du Plessis', 'Tamim Iqbal', 'AE Jones',
       'KJ Coetzer', 'MJ Guptill', 'PS Airee', 'AC Gilchrist',
       'Tamim Iqbal', 'G Gambhir', 'T Duffin', 'AJ Finch', 'HK Matthews',
       'WU Tharanga', 'Noor Ali Zadran', 'Jitin Singh', 'Tamim Iqbal',
       'LMP Simmons', 'WU Tharanga', 'J Dunn', 'Tamim Iqbal',
       'Tamim Iqbal', 'Tamim Iqbal', 'HM Amla', 'CR Suryawanshi',
       'MP Stoinis', 'NE Bolton', 'M Vohra', 'S Dhawan', 'CH Gayle',
       'LA Pomersbach', 'MS Wade', 'BA Parchment', 'DS Smith',
       'LMP Simmons', 'RS Bopara', 'Jitin Singh', 'HM Amla', 'L Lee',
       'LMP Simmons', 'DA Warner', 'HH Gibbs', 'Tamim Iqbal',
       'Jitin Singh', 'M Vijay', 'Tamim Iqbal', 'WU Tharanga',
       'Tamim Iqbal', 'PJ Hughes', 'H Masakadza', 'MS Wade',
       'AC Gilchrist', 'Tamim Iqbal', 'Kamran Akmal', 'RJ Nicol',
       'CH Gayle', 'MDKJ Perera', 'RS Bopara', 'HM Amla', 'WU Tharanga',
       'Tamim Iqbal', 'AN Cook', 'CJ Simmons', 'MJ Guptill', 'SC Ganguly',
       'CM Edwards', 'Tamim Iqbal', 'SP Fleming', 'ST Jayasuriya',
       'MS Atapattu', 'AJ Finch', 'Tamim Iqbal', 'AC Jayangani',
       'FDM Karunaratne', 'Mohammad Hafeez', 'G Gambhir', 'PA Patel',
       'Tamim Iqbal', 'TA Kurukulasuriya', 'Noor Ali Zadran',
       'AB de Villiers', 'WU Tharanga', 'S Sohal', 'Tamim Iqbal',
       'PG Raut', 'AJ Strauss', 'SA Asnodkar', 'HM Amla',
       'FDM Karunaratne', 'Tamim Iqbal', 'RG Sharma', 'DR Smith',
       'MH Cross', 'Imrul Kayes', 'KJ Coetzer', 'L Vincent', 'MM Lanning',
       'WTS Porterfield', 'Zeeshan Siddiqui', 'J Chinunga',
       'AC Gilchrist', 'Imrul Kayes', 'HK Matthews', 'Karim Sadiq',
       'V Sehwag', 'Tamim Iqbal', 'LMP Simmons', 'SJ Myburgh',
       'Imrul Kayes', 'GC Smith', 'AN Cook', 'V Sehwag', 'S Vidyut',
       'Manpreet Singh', 'Tamim Iqbal', 'MS Harris', 'WTS Porterfield',
       'KJ Coetzer', 'Rizwan Cheema', 'AN Cook', 'CA Lynn', 'Tamim Iqbal',
       'HM Amla', 'AC Jayangani', 'MH Cross', 'Tamim Iqbal',
       'H Masakadza', 'ST Jayasuriya', 'MJ Guptill', 'Tamim Iqbal',
       'SR Watson', 'SR Watson', 'H Patel', 'Kamran Akmal', 'Rajin Saleh',
       'HM Amla', 'AN Cook', 'WU Tharanga', 'HM Amla', 'HM Amla',
       'MDKJ Perera', 'NE Bolton', 'AM Rahane', 'WU Tharanga', 'HM Amla',
       'JJ Roy', 'AJ Finch', 'Shahriar Nafees', 'AK Markram', 'L Lee',
       'V Sehwag', 'SJ Myburgh', 'AJ Strauss', 'Zeeshan Maqsood',
       'SR Watson', 'ST Jayasuriya', 'DA Warner', 'AM Rahane',
       'WU Tharanga', 'M Vijay', 'IR Bell', 'AN Cook', 'Noor Ali Zadran',
       'RS Bopara', 'SJ Myburgh', 'AA Mulla', 'WU Tharanga', 'Azhar Ali',
       'WTS Porterfield', 'CJ Chibhabha', 'AK Markram', 'CM Edwards',
       'MJ Guptill', 'HH Gibbs', 'SC Ganguly', 'A Mutreja', 'CH Gayle',
       'Tamim Iqbal', 'Noor Ali Zadran', 'J Kida', 'SA Yadav',
       'Sagar Pun', 'N Mapunda', 'DA Warner', 'H Masakadza',
       'DPMD Jayawardene'
]
from collections import Counter
Player1_counts = Counter(Player1)
top_four = Player1_counts.most_common(4)
print(top_four)
# Out:
# [('Tamim Iqbal', 60), ('WU Tharanga', 21), ('HM Amla', 19), ('LMP Simmons', 14)]

# %%
x = MD[["Player2_StrikeRate"]]
y= MD[["Players_2"]]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.75)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier()

rf.fit(x_train, y_train.values.ravel())
#print("Accuracy score (validation): {0:.3f}".format(rf.score(x_test, y_test)))
result2= rf.predict(x_test)
result2
# Out:
# array(['HM Amla', 'IR Bell', 'AB Barath', ..., 'TT Beaumont', 'G Gambhir',
#        'BRM Taylor'], dtype=object)

# %%
result2_counts = Counter(result2)
top_four2 = result2_counts.most_common(4)
print(top_four2)
# Out:
# [('KC Sangakkara', 134), ('AJ Finch', 47), ('S Dhawan', 38), ('Ahmed Shehzad', 28)]

# %%
x = MD[["Player3_StrikeRate"]]
y= MD[["Players_3"]]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier()

rf.fit(x_train, y_train.values.ravel())
#print("Accuracy score (validation): {0:.3f}".format(rf.score(x_test, y_test)))
result3= rf.predict(x_test)
result3
# Out:
# array(['RT Ponting', 'Mohammad Hafeez', 'Mominul Haque', 'EC Joyce',
#        'JK Kamande', 'RT Ponting', 'AT Rayudu', 'MN van Wyk', 'IR Bell',
#        'IJL Trott', 'TLW Cooper', 'KD Karthik', 'Yuvraj Singh',
#        'AE Satterthwaite', 'JH Kallis', 'MW Machan', 'MW Machan',
#        'RT Ponting', 'KD Karthik', 'KC Sangakkara', 'BB McCullum',
#        'RT Ponting', 'AC Jayangani', 'KC Sangakkara', 'MS Bisla',
#        'SPD Smith', 'IR Bell', 'CK Coventry', 'IR Bell', 'IR Bell',
#        'MS Dhoni', 'OA Shah', 'S Chanderpaul', 'Aftab Ahmed', 'JP Duminy',
#        'GP Meade', 'Mohammad Hafeez', 'MJ Prior', 'JK Vifah',
#        'F du Plessis', 'AC Jayangani', 'MK Pandey', 'TM Dilshan',
#        'AC Jayangani', 'TM Dilshan', 'DM Bravo', 'KE Bryce',
#        'KP Pietersen', 'GJ Bailey', 'F du Plessis', 'CH Morris',
#        'Khurram Khan', 'Nizakat Khan', 'F du Plessis', 'V Kohli',
#        'TM Dilshan', 'S Chanderpaul', 'Asad Shafiq', 'JE Root', 'T Taibu',
# ...

# %%
result3_counts = Counter(result3)
top_four3 = result3_counts.most_common(4)
print(top_four3)
# Out:
# [('TM Dilshan', 46), ('KC Sangakkara', 31), ('F du Plessis', 21), ('RT Ponting', 17)]

# %%
x = MD[['Player4_StrikeRate']]
y= MD[['Players_4']]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier()

rf.fit(x_train, y_train.values.ravel())
#print("Accuracy score (validation): {0:.3f}".format(rf.score(x_test, y_test)))
result4= rf.predict(x_test)
result4
# Out:
# array(['KC Sangakkara', 'EJG Morgan', 'MS Dhoni', 'HH Gibbs', 'PM Selowa',
#        'AE Paraam', 'LD Chandimal', 'Tamoor Sajjad', 'L Tucker',
#        'BRM Taylor', 'JH Kallis', 'S Prasanna', 'JH Davey',
#        'LD Chandimal', 'DPMD Jayawardene', 'Yuvraj Singh', 'KP Pietersen',
#        'V Kohli', 'Mahmudullah', 'Samiullah Shenwari', 'CR Suryawanshi',
#        'JE Root', 'Samiullah Shenwari', 'T Maruma', 'DPMD Jayawardene',
#        'JE Root', 'RR Sarwan', 'MJ Clarke', 'GJ Maxwell',
#        'DPMD Jayawardene', 'DC Stovell', 'RR Rossouw', 'SN Khan',
#        'DPMD Jayawardene', 'Mushfiqur Rahim', 'SE Marsh', 'DM Bravo',
#        'AB de Villiers', 'JP Duminy', 'AB de Villiers', 'LRPL Taylor',
#        'JE Root', 'Shakib Al Hasan', 'R Gaznavi', 'RR Pant',
#        'Raqibul Hasan', 'JE Root', 'SO Tikolo', 'SD Hope',
#        'DPMD Jayawardene', 'MEK Hussey', 'Younis Khan', 'MN Samuels',
#        'Umar Akmal', 'M Vohra', 'Mohammad Ashraful', 'KC Sangakkara',
# ...

# %%
result4_counts = Counter(result4)
top_four4 = result4_counts.most_common(4)
print(top_four4)
# Out:
# [('DPMD Jayawardene', 59), ('LRPL Taylor', 19), ('AB de Villiers', 17), ('LD Chandimal', 15)]

# %%
x = MD[['Player5_StrikeRate']]
y= MD[['Players_5']]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier()

rf.fit(x_train, y_train.values.ravel())
#print("Accuracy score (validation): {0:.3f}".format(rf.score(x_test, y_test)))
result5= rf.predict(x_test)
result5
# Out:
# array(["KJ O'Brien", 'Shakib Al Hasan', 'KD Karthik', 'Shakib Al Hasan',
#        'CK Coventry', 'PD Collingwood', 'Shakib Al Hasan', 'DL Vettori',
#        'Habibul Bashar', 'A Flintoff', 'Shakib Al Hasan', 'JH Mensah',
#        'Shakib Al Hasan', 'CK Kapugedera', 'LC Sthalekar', 'ML Green',
#        'M Kapp', "NJ O'Brien", 'CS Sandri', 'SA Yadav', 'Shakib Al Hasan',
#        'SB Styris', 'JP Duminy', 'KS Williamson', 'LPC Silva',
#        'MT Renshaw', 'RV Uthappa', 'SK Raina', 'Samiullah Shenwari',
#        'M Kapp', 'MEK Hussey', 'HC Knight', 'A Flintoff', 'MN Waller',
#        'CD McMillan', 'Shahid Afridi', 'Samiullah Shenwari',
#        'Yuvraj Singh', 'ML Green', 'KA Pollard', 'Asad Shafiq',
#        'Nigar Sultana', 'Shoaib Malik', 'Shakib Al Hasan', 'SR Watson',
#        'JP Duminy', 'JP Duminy', 'SMA Priyanjan', 'CL White',
#        'Asghar Stanikzai', 'SR Patel', 'OJ Bejide', 'Sasha Azmi',
#        'M Kapp', 'Umar Akmal', 'ELT de Lange', 'DM de Silva',
# ...

# %%
result5_counts = Counter(result5)
top_four5 = result5_counts.most_common(4)
print(top_four5)
# Out:
# [('Shakib Al Hasan', 54), ('JP Duminy', 12), ('SK Raina', 11), ('MEK Hussey', 11)]

# %%
x = MD[['Player15_StrikeRate']]
y= MD[['Players_15']]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier()

rf.fit(x_train, y_train.values.ravel())
#print("Accuracy score (validation): {0:.3f}".format(rf.score(x_test, y_test)))
result6= rf.predict(x_test)
result6
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-b9c2b570715d> in <module>
#       8 rf = RandomForestClassifier()
#       9
# ---> 10 rf.fit(x_train, y_train.values.ravel())
#      11 #print("Accuracy score (validation): {0:.3f}".format(rf.score(x_test, y_test)))
#      12 result6= rf.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     301                 "sparse multilabel-indicator for y is not supported."
#     302             )
# --> 303         X, y = self._validate_data(X, y, multi_output=True,
#     304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
